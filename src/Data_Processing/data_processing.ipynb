# %% [markdown]
# # 🧼 Data Processing
#
# This notebook performs the essential preprocessing steps required to prepare the employee dataset for machine learning modeling. It includes data loading, cleaning, encoding, and saving the processed output.

# %%
# 📥 Load Raw Employee Dataset

import pandas as pd

file_path = '../../data/raw/employee_data.xlsx'
df = pd.read_excel(file_path)

df.head()
# Out:
#   EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 0  E1001007   40    Male       Life Sciences       Married         Sales
# 1  E1001025   30    Male           Marketing      Divorced         Sales
# 2  E1001054   52    Male           Marketing       Married         Sales
# 3  E1001059   25  Female             Medical        Single         Sales
# 4  E1001064   34    Male               Other        Single         Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive       Travel_Frequently                 5
# 1  Sales Executive           Travel_Rarely                27
# 2          Manager           Travel_Rarely                 3
# 3  Sales Executive           Travel_Rarely                26
# 4  Sales Executive           Travel_Rarely                 2
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  4  ...                            3
# 1                  5  ...                            4
# 2                  4  ...                            1
# 3                  1  ...                            2
# 4                  3  ...                            3
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          20                      2                   3
# 1                          10                      2                   2
# 2                          34                      3                   4
# 3                           6                      5                   2
# 4                           6                      5                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            18                            13
# 1                             8                             7
# 2                            34                             6
# 3                             6                             5
# 4                             6                             5
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       1                    12         No                  4
# 1                       7                     7         No                  4
# 2                       1                    16         No                  4
# 3                       1                     4         No                  4
# 4                       1                     4         No                  4
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 🔍 1. Inspect Dataset Structure
#
# We inspect the dataset to understand its shape, column types, and sample records.

# %%
# 🔍 Inspect Dataset Structure

print("Shape:", df.shape)
print("\nColumns:\n", df.columns.tolist())
print("\nData Types:\n", df.dtypes)

df.describe(include='all')
# Out:
# Shape: (86, 28)
#
# Columns:
#  ['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus', 'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency', 'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction', 'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel', 'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime', 'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction', 'TotalWorkExperienceInYears', 'TrainingTimesLastYear', 'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany', 'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition', 'PerformanceRating']
#
# Data Types:
#  EmpNumber                       object
# Age                              int64
# Gender                          object
# EducationBackground             object
# MaritalStatus                   object
# EmpDepartment                   object
# EmpJobRole                      object
# BusinessTravelFrequency         object
# DistanceFromHome                 int64
# EmpEducationLevel                int64
# EmpEnvironmentSatisfaction       int64
# EmpHourlyRate                    int64
# EmpJobInvolvement                int64
# EmpJobLevel                      int64
# EmpJobSatisfaction               int64
# NumCompaniesWorked               int64
# OverTime                        object
# EmpLastSalaryHikePercent         int64
# EmpRelationshipSatisfaction      int64
# TotalWorkExperienceInYears       int64
# TrainingTimesLastYear            int64
# EmpWorkLifeBalance               int64
# ExperienceYearsAtThisCompany     int64
# ExperienceYearsInCurrentRole     int64
# YearsSinceLastPromotion          int64
# YearsWithCurrManager             int64
# Attrition                       object
# PerformanceRating                int64
# dtype: object
#        EmpNumber        Age Gender EducationBackground MaritalStatus  \
# count         86  86.000000     86                  86            86
# unique        86        NaN      2                   6             3
# top     E1001007        NaN   Male       Life Sciences       Married
# freq           1        NaN     53                  35            36
# mean         NaN  37.209302    NaN                 NaN           NaN
# std          NaN   9.577076    NaN                 NaN           NaN
# min          NaN  18.000000    NaN                 NaN           NaN
# 25%          NaN  31.000000    NaN                 NaN           NaN
# 50%          NaN  37.000000    NaN                 NaN           NaN
# 75%          NaN  43.000000    NaN                 NaN           NaN
# max          NaN  60.000000    NaN                 NaN           NaN
#
#                  EmpDepartment       EmpJobRole BusinessTravelFrequency  \
# count                       86               86                      86
# unique                       4               12                       3
# top     Research & Development  Sales Executive           Travel_Rarely
# freq                        41               25                      53
# mean                       NaN              NaN                     NaN
# std                        NaN              NaN                     NaN
# min                        NaN              NaN                     NaN
# 25%                        NaN              NaN                     NaN
# 50%                        NaN              NaN                     NaN
# 75%                        NaN              NaN                     NaN
# max                        NaN              NaN                     NaN
#
#         DistanceFromHome  EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# count          86.000000          86.000000  ...                    86.000000
# unique               NaN                NaN  ...                          NaN
# top                  NaN                NaN  ...                          NaN
# freq                 NaN                NaN  ...                          NaN
# mean            8.918605           2.906977  ...                     2.534884
# std             8.569735           1.047438  ...                     1.048222
# min             1.000000           1.000000  ...                     1.000000
# 25%             2.000000           2.000000  ...                     2.000000
# 50%             6.500000           3.000000  ...                     3.000000
# 75%            12.000000           4.000000  ...                     3.000000
# max            29.000000           5.000000  ...                     4.000000
#
#         TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# count                    86.000000              86.000000           86.000000
# unique                         NaN                    NaN                 NaN
# top                            NaN                    NaN                 NaN
# freq                           NaN                    NaN                 NaN
# mean                     11.790698               2.755814            3.069767
# std                       8.330124               1.094758            0.664932
# min                       0.000000               0.000000            2.000000
# 25%                       7.000000               2.000000            3.000000
# 50%                      10.000000               3.000000            3.000000
# 75%                      14.750000               3.000000            3.750000
# max                      36.000000               6.000000            4.000000
#
#         ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# count                      86.000000                     86.000000
# unique                           NaN                           NaN
# top                              NaN                           NaN
# freq                             NaN                           NaN
# mean                        7.558140                      4.546512
# std                         7.310918                      3.927750
# min                         0.000000                      0.000000
# 25%                         3.000000                      2.000000
# 50%                         6.000000                      4.000000
# 75%                         8.750000                      7.000000
# max                        36.000000                     15.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# count                86.000000             86.000000         86
# unique                     NaN                   NaN          2
# top                        NaN                   NaN         No
# freq                       NaN                   NaN         75
# mean                  2.151163              4.197674        NaN
# std                   3.414562              3.946166        NaN
# min                   0.000000              0.000000        NaN
# 25%                   0.000000              1.000000        NaN
# 50%                   1.000000              3.500000        NaN
# 75%                   2.000000              7.000000        NaN
# max                  15.000000             17.000000        NaN
#
#         PerformanceRating
# count                86.0
# unique                NaN
# top                   NaN
# freq                  NaN
# mean                  4.0
# std                   0.0
# min                   4.0
# 25%                   4.0
# 50%                   4.0
# 75%                   4.0
# max                   4.0
#
# [11 rows x 28 columns]

# %% [markdown]
# ### ❓ 2. Handle Missing Values
#
# We identify missing values and apply appropriate imputation strategies. For simplicity, we fill missing numerical values with 0 and categorical values with `'Unknown'`. This ensures the dataset is complete and ready for encoding.

# %%
# ❓ Handle Missing Values (Safe Version)

# Check missing values
missing = df.isnull().sum()
print("Missing values per column:\n", missing[missing > 0])

# Fill missing values safely
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].fillna('Unknown')
    else:
        df[col] = df[col].fillna(0)

# Confirm no missing values remain
df.isnull().sum().sum()
# Out:
# Missing values per column:
#  Series([], dtype: int64)
# np.int64(0)

# %% [markdown]
# ### 🔄 3. Encode Categorical Variables
#
# We apply Label Encoding to convert categorical features into numerical values. The column `EmpNumber` is excluded as it is a unique identifier and not a predictive feature.

# %%
# 🔄 Encode Categorical Variables (excluding EmpNumber)

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# Categorical columns to encode (excluding EmpNumber)
cat_cols = [
    'Gender', 'EducationBackground', 'MaritalStatus',
    'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
    'OverTime', 'Attrition'
]

# Apply Label Encoding
for col in cat_cols:
    df[col] = le.fit_transform(df[col])

# %% [markdown]
# ### 💾 4. Save Processed Dataset
#
# We save the cleaned and encoded dataset to the `data/processed/` directory for use in modeling and analysis.

# %%
# 💾 Save Processed Dataset

output_path = '../../data/processed/employee_data_cleaned.csv'
df.to_csv(output_path, index=False)

print("✅ Dataset saved to:", output_path)
# Out:
# ✅ Dataset saved to: ../../data/processed/employee_data_cleaned.csv
